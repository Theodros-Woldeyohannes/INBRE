# %%
#import packages
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mplt
import os
import matplotlib.pyplot as plt
import scipy as sp
from scipy.stats import f_oneway
from scipy.stats import normaltest
from scipy.stats import kruskal
from itertools import groupby

#set base path
path = r'C:\Users\jacks\Documents\UNM\P30\AIRWISE\PurpleAir Download 9-30-2024\Daily_data/'

# %%
#create empty dict to hold station data
dfs = {}
dfs_or = {}
#dfsl = []

def drop_outliers_IQR(data):
    q1, q3 = np.percentile(data, [25, 75])
    iqr = q3 - q1

    lower_bound = q1 - (iqr * 1.5)
    upper_bound = q3 + (iqr * 1.5)

    return data[(data >= lower_bound) & (data <= upper_bound)]

#loop through station data CSVs
for root, dirs, files in os.walk(path):
    for file_name in files:
        if file_name.endswith('.csv'):
            file_path = os.path.join(root, file_name)

            # Read the CSV file into a DataFrame
            df = pd.read_csv(file_path)

            #define pm2.5 data as array, append to dict
            #Data_type = object
            dfa = np.array(df['pm2.5_atm'])
            dfa_or = drop_outliers_IQR(dfa)
            #dfsl.append(dfa)
            dfs[f'{file_name[:-4]}'] = dfa
            dfs_or[f'{file_name[:-4]}'] = dfa_or

            # s, p = normaltest(dfa, nan_policy='omit')
            # print('s value is: ' + str(s))
            # print('p value is: ' + str(p))

            # s_or, p_or = normaltest(dfa_or, nan_policy='omit')
            # print('s value is (outliers removed): ' + str(s_or))
            # print('p value is (outliers removed): ' + str(p_or))

#create boxplot
bpc = sb.boxplot(dfs, orient='v').set(xlabel='station', ylabel='pm2.5 (ug/m3) 1-day average')
plt.show()
bpc_or = sb.boxplot(dfs_or, orient='v', showfliers=False).set(xlabel='station', ylabel='pm2.5 (ug/m3) 10-minute average (outliers removed)')
plt.show()
# Out:
# s value is: 13.470819573803144
# p value is: 0.0011880882373911583
# s value is (outliers removed): 10.456749883101734
# p value is (outliers removed): 0.005362232166851149
# s value is: 82.08815699507514
# p value is: 1.495488899344581e-18
# s value is (outliers removed): 20.530759597685353
# p value is (outliers removed): 3.481786994404771e-05
# s value is: 126.11615700315181
# p value is: 4.113622808855868e-28
# s value is (outliers removed): 26.160668365654416
# p value is (outliers removed): 2.0858498521169964e-06
# s value is: 121.9308630441814
# p value is: 3.334644205765757e-27
# s value is (outliers removed): 31.406814246999794
# p value is (outliers removed): 1.5138991292393767e-07
# s value is: 63.29903347651461
# p value is: 1.7979993304427375e-14
# s value is (outliers removed): 17.454151536726762
# p value is (outliers removed): 0.00016213588656708065
# s value is: 298.41944513091244
# p value is: 1.5813967557644964e-65
# s value is (outliers removed): 31.07679695511166
# p value is (outliers removed): 1.785497652694187e-07
# s value is: 42.723949972098744
# p value is: 5.279735194433547e-10
# s value is (outliers removed): 16.07855535232363
# p value is (outliers removed): 0.00032254184565982437
# s value is: 35.673459303836836
# p value is: 1.7931091923825685e-08
# s value is (outliers removed): 8.596930250706425
# p value is (outliers removed): 0.013589401040280728
# s value is: 83.7326200068515
# p value is: 6.571924838346029e-19
# s value is (outliers removed): 26.971661000938006
# p value is (outliers removed): 1.390523169821148e-06
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23828\1979588581.py in ?()
#      28     return data[(data >= lower_bound) & (data <= upper_bound)]
#      29
#      30 #loop through station data CSVs
#      31 for root, dirs, files in os.walk(path):
# ---> 32     for file_name in files:
#      33         if file_name.endswith('.csv'):
#      34             file_path = os.path.join(root, file_name)
#      35
#
# c:\ProgramData\anaconda3\envs\lap_env\lib\site-packages\scipy\stats\_axis_nan_policy.py in ?(***failed resolving arguments***)
#     527                 # behavior of those would break backward compatibility.
#     528
#     529                 if sentinel:
#     530                     samples = _remove_sentinel(samples, paired, sentinel)
# --> 531                 res = hypotest_fun_out(*samples, **kwds)
#     532                 res = result_to_tuple(res)
#     533                 res = _add_reduced_axes(res, reduced_axes, keepdims)
#     534                 return tuple_to_result(*res)
#
# c:\ProgramData\anaconda3\envs\lap_env\lib\site-packages\scipy\stats\_stats_py.py in ?(a, axis, nan_policy)
#    1949     can be used to exactly control the rate of false rejections of the null
#    1950     hypothesis [5]_.
#    1951
#    1952     """
# -> 1953     s, _ = skewtest(a, axis)
#    1954     k, _ = kurtosistest(a, axis)
#    1955     k2 = s*s + k*k
#    1956
#
# c:\ProgramData\anaconda3\envs\lap_env\lib\site-packages\scipy\stats\_axis_nan_policy.py in ?(***failed resolving arguments***)
#     527                 # behavior of those would break backward compatibility.
#     528
#     529                 if sentinel:
#     530                     samples = _remove_sentinel(samples, paired, sentinel)
# --> 531                 res = hypotest_fun_out(*samples, **kwds)
#     532                 res = result_to_tuple(res)
#     533                 res = _add_reduced_axes(res, reduced_axes, keepdims)
#     534                 return tuple_to_result(*res)
#
# c:\ProgramData\anaconda3\envs\lap_env\lib\site-packages\scipy\stats\_stats_py.py in ?(a, axis, nan_policy, alternative)
#    1579     """
#    1580     b2 = skew(a, axis)
#    1581     n = a.shape[axis]
#    1582     if n < 8:
# -> 1583         raise ValueError(
#    1584             "skewtest is not valid with less than 8 samples; %i samples"
#    1585             " were given." % int(n))
#    1586     y = b2 * math.sqrt(((n + 1) * (n + 3)) / (6.0 * (n - 2)))
#
# ValueError: skewtest is not valid with less than 8 samples; 1 samples were given.

# %%
ad = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in dfs.items()]))
ad
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
ad_or = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in dfs_or.items()]))
ad_or
# Out:
#     Crow_24hr  Hardin_24hr  Pryor_24hr  Wyola_24hr
# 0    1.205833     0.050867    3.438800    0.845161
# 1    5.038183     0.024895    3.008700    3.461618
# 2    1.797824     0.472965    0.820642    1.146582
# 3    1.891245     1.872081    2.080534    0.086641
# 4    1.574038     1.575690    1.029295    0.581760
# 5    2.914818     2.096292    0.413071    1.538514
# 6    3.660462     3.474742    0.376843    1.362702
# 7    4.646860     6.941864    1.449511    2.134097
# 8    4.876536     3.393853    1.778847    0.974537
# 9   13.761884     3.942201    1.987184    2.914269
# 10   5.923825     6.117765    1.044099    3.079369
# 11   7.391297     4.463312    2.839753    3.589023
# 12   4.833128     5.210966    3.516646    3.533865
# 13   5.813050    12.143776    3.386220    4.596931
# 14   6.104466    19.814465    2.673801    6.188603
# 15  14.468886    18.581367    3.909253   13.362909
# 16  21.852405    18.309533    4.900230   18.642342
# 17  24.927714    16.709452   20.751484   18.890688
# 18  40.204427    22.388198   20.050537   24.022928
# 19  23.148434    23.547559   18.367284   14.393122
# 20  21.275480    17.398149   22.058762   13.390864
# 21  23.840945    23.654361   24.597091   41.823237
# 22  29.118572    24.710847   12.416575   46.040556
# 23  27.809651    20.877966   10.437388   23.261017
# 24  26.590273    39.135066   33.400418   20.157897
# 25  22.961604    48.823524   28.025146   39.742343
# 26  45.159947    41.884515   27.535286   49.575376
# 27  56.477971    29.832260   16.332994   39.601456
# 28  46.636506    24.262220   36.981469   27.165196
# 29  33.693694    35.381027   47.403655   23.955118
# 30  29.316610    39.434436   36.745090   32.076362
# 31  39.103618    45.222709   26.411910   40.102667
# 32  51.194247    22.612891   24.644652   43.804108
# 33  50.369986     2.334264   43.546558   22.134090
# 34  26.658049     6.650930   43.580926    2.911634
# 35   3.528538    15.511801   51.445341    6.351820
# 36   7.713279    18.875098   52.732200   15.951845
# 37  17.574407    25.168455   14.772469   17.393291
# 38  21.955260    19.190236    2.623992   17.453467
# 39  25.305802    22.746368    7.300605   15.501571
# 40  22.321921    26.249262   19.299264   18.691566
# 41  25.618366    37.850195   15.678096   20.866197
# 42  22.865517    18.588713   15.836669   29.923847
# 43  37.290877    22.149896   14.824548   25.061750
# 44  24.687152    20.092796   23.804107   21.869248
# 45  24.587413    16.690560   17.337497   19.257609
# 46  21.162235    12.657781   29.654560   16.262778
# 47  19.470469    18.632236   25.464555    8.969545
# 48  14.728619    27.069771   19.256583   16.870762
# 49  20.147519    25.640708   22.782976   25.767798
# 50  34.037828    22.241819   11.559768   18.043664
# 51  34.200088    15.079416    7.864965   18.602458
# 52  24.321887    11.434924   15.834896    9.733692
# 53  15.563511     1.726393   11.423039    5.995434
# 54  11.658776          NaN   10.106979    1.765480
# 55   3.920477          NaN   19.156424         NaN
# 56        NaN          NaN   19.900431         NaN
# 57        NaN          NaN    6.350729         NaN
# 58        NaN          NaN    1.567649         NaN

# %%
ad.describe()
# Out:
#        Crow_24hr  Hardin_24hr  Pryor_24hr  Wyola_24hr
# count  57.000000    55.000000   59.000000   57.000000
# mean   21.428000    18.655230   16.415576   19.821073
# std    15.173000    13.341569   13.956462   22.892088
# min     1.205833     0.024895    0.376843    0.086641
# 25%     6.104466     6.384347    3.412510    3.589023
# 50%    21.955260    18.632236   15.678096   17.393291
# 75%    27.809651    24.486533   24.200599   24.022928
# max    62.493615    55.094212   52.732200  153.533336

# %%
ad_or.describe()
# Out:
#        Crow_24hr  Hardin_24hr  Pryor_24hr  Wyola_24hr
# count  56.000000    54.000000   59.000000   55.000000
# mean   20.694686    17.980434   16.415576   16.753116
# std    14.254707    12.483555   13.956462   13.418650
# min     1.205833     0.024895    0.376843    0.086641
# 25%     6.059306     6.251056    3.412510    3.561444
# 50%    21.903832    18.610475   15.678096   16.870762
# 75%    26.945950    24.110255   24.200599   23.608068
# max    56.477971    48.823524   52.732200   49.575376

# %%
outpath = r'C:\Users\jacks\Documents\UNM\P50\INBRE\PM_data\Output_tables/'
ad.to_csv(outpath + 'datacomb.csv')

# %%
ad_or.to_csv(outpath + 'datacomb_or.csv')

# %%
hpc = sb.histplot(ad, bins=16, binwidth=4).set(xlabel='pm2.5 (ug/m3) 1-day average')

# %%
hpc_or = sb.histplot(ad_or).set(xlabel='pm2.5 (ug/m3) 10-minute average (outliers removed)')

# %%
adm = pd.melt(ad)
adm
# Out:
#        variable     value
# 0     Crow_24hr  1.205833
# 1     Crow_24hr  5.038183
# 2     Crow_24hr  1.797824
# 3     Crow_24hr  1.891245
# 4     Crow_24hr  1.574038
# ..          ...       ...
# 231  Wyola_24hr  9.733692
# 232  Wyola_24hr  5.995434
# 233  Wyola_24hr  1.765480
# 234  Wyola_24hr       NaN
# 235  Wyola_24hr       NaN
#
# [236 rows x 2 columns]

# %%
adm_or = pd.melt(ad_or)
adm_or
# Out:
#        variable     value
# 0     Crow_24hr  1.205833
# 1     Crow_24hr  5.038183
# 2     Crow_24hr  1.797824
# 3     Crow_24hr  1.891245
# 4     Crow_24hr  1.574038
# ..          ...       ...
# 231  Wyola_24hr  1.765480
# 232  Wyola_24hr       NaN
# 233  Wyola_24hr       NaN
# 234  Wyola_24hr       NaN
# 235  Wyola_24hr       NaN
#
# [236 rows x 2 columns]

# %%
adm_clean = adm.dropna()
adm_clean
# Out:
#        variable      value
# 0     Crow_24hr   1.205833
# 1     Crow_24hr   5.038183
# 2     Crow_24hr   1.797824
# 3     Crow_24hr   1.891245
# 4     Crow_24hr   1.574038
# ..          ...        ...
# 229  Wyola_24hr  18.043664
# 230  Wyola_24hr  18.602458
# 231  Wyola_24hr   9.733692
# 232  Wyola_24hr   5.995434
# 233  Wyola_24hr   1.765480
#
# [228 rows x 2 columns]

# %%
adm_clean_or = adm_or.dropna()
adm_clean_or
# Out:
#        variable      value
# 0     Crow_24hr   1.205833
# 1     Crow_24hr   5.038183
# 2     Crow_24hr   1.797824
# 3     Crow_24hr   1.891245
# 4     Crow_24hr   1.574038
# ..          ...        ...
# 227  Wyola_24hr  18.043664
# 228  Wyola_24hr  18.602458
# 229  Wyola_24hr   9.733692
# 230  Wyola_24hr   5.995434
# 231  Wyola_24hr   1.765480
#
# [224 rows x 2 columns]

# %%
adm_clean.to_csv(outpath + 'datacomb_melt.csv')

# %%
adm_clean_or.to_csv(outpath + 'datacomb_melt_or.csv')

# %%
result = adm_clean.groupby('variable')['value'].apply(list)
result
# Out:
# variable
# Crow_24hr      [1.20583333333333, 5.03818309859155, 1.7978242...
# Hardin_24hr    [0.0508673469387755, 0.024895251396648, 0.4729...
# Pryor_24hr     [3.4388, 3.00869985141159, 0.820641748942172, ...
# Wyola_24hr     [0.845161290322581, 3.46161764705882, 1.146582...
# Name: value, dtype: object

# %%
result_or = adm_clean_or.groupby('variable')['value'].apply(list)
result_or
# Out:
# variable
# Crow_24hr      [1.20583333333333, 5.03818309859155, 1.7978242...
# Hardin_24hr    [0.0508673469387755, 0.024895251396648, 0.4729...
# Pryor_24hr     [3.4388, 3.00869985141159, 0.820641748942172, ...
# Wyola_24hr     [0.845161290322581, 3.46161764705882, 1.146582...
# Name: value, dtype: object

# %%
F, p = f_oneway(*result)
print(F)
print(p)
# Out:
# 0.9154590527716091
# 0.4341856130178484

# %%
H, p = kruskal(*result)
print(H)
print(p)
# Out:
# 5.313263547167367
# 0.1502440513040995

# %%
F, p = f_oneway(*result_or)
print(F)
print(p)
# Out:
# 1.159407056223056
# 0.3261410902647063

# %%
H, p = kruskal(*result_or)
print(H)
print(p)
# Out:
# 5.298461950251294
# 0.15120222395421146
